# %% [markdown]
# # image resizing and compression python
#
# ## D.r Molavi
#
# ### Muhammad Hassanzadeh
#  given the following image we will go on manupilating it with package called opencv with is a package for visual works
# ![Religion_of_Nobel_Prize_winners.png](attachment:Religion_of_Nobel_Prize_winners.png)

# %%
import numpy as np #numerical python no need to for loops in arrays and data structures so fast and rapid
import pandas as pd # great library for coping with matrices and its built on the numpy for data analysis
import cv2#open source library for image... manupolatin and detectinfg stuff for machine learning hidden pattern
#import skimage as io
import matplotlib.pyplot as plt #for plotting and showing images

# %%
img=cv2.imread(r'C:\Users\Acer\Downloads\Religion_of_Nobel_Prize_winners.png',)
print(img.shape)
img
# Out:
# (639, 978, 3)
# array([[[191, 191, 191],
#         [191, 191, 191],
#         [191, 191, 191],
#         ...,
#         [191, 191, 191],
#         [191, 191, 191],
#         [203, 203, 203]],
#
#        [[191, 191, 191],
#         [193, 193, 193],
#         [193, 193, 193],
#         ...,
#         [193, 193, 193],
#         [192, 192, 192],
#         [191, 191, 191]],
#
#        [[191, 191, 191],
#         [193, 193, 193],
#         [194, 194, 194],
#         ...,
#         [193, 193, 193],
#         [192, 192, 192],
#         [191, 191, 191]],
#
#        ...,
#
#        [[191, 191, 191],
#         [191, 191, 191],
#         [191, 191, 191],
#         ...,
#         [191, 191, 191],
#         [191, 191, 191],
#         [191, 191, 191]],
#
#        [[191, 191, 191],
#         [191, 191, 191],
#         [191, 191, 191],
#         ...,
#         [191, 191, 191],
#         [191, 191, 191],
#         [191, 191, 191]],
#
#        [[191, 191, 191],
#         [191, 191, 191],
#         [191, 191, 191],
#         ...,
#         [191, 191, 191],
#         [191, 191, 191],
#         [195, 195, 195]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
plt.imshow(img[::2,::3])#steps got 2 and 8

# %%
half = cv2.resize(img, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(img, (1050, 1610))
 
stretch_near = cv2.resize(img, (780, 540),
               interpolation = cv2.INTER_NEAREST)
 
 
Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[img, half, bigger, stretch_near]
count = 4
 
for i in range(count):
    plt.subplot(4, 4, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
 
plt.show()

# %%
plt.imshow(half)

# %%
plt.imshow(bigger)

# %%
plt.imshow(stretch_near)

# %%
capture=cv2.VideoCapture(0)#first webcam and one for second webcam
while True:
    ret ,frame=capture.read() #return fals if ur camera dont work
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow('GRAY',gray)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1)==ord('q'):#press q in webcam windows to end the program
        break
capture.release()
cv2.destroyAllWindows()
